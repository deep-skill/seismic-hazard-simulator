# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import os
import shutil
import subprocess
import re



# ========= Variables de entrada =============

# 1. Aceleraciones espectrales para las gráficas

ts_list = ['PGA', 'SA(0.2)', 'SA(0.5)', 'SA(1.0)', 'SA(2.0)']
ts_values = [0.01, 0.20, 0.50, 1.00, 2.00]

# 2. Gráficas de las Curvas de Peligro

hazard_curve_x_lim = (0.01, 10.00)
hazard_curve_x_ticks = [0.01, 1.00, 10.00]

hazard_curve_y_lim = (0.0001, 1)
hazard_curve_y_ticks = [0.0001, 0.001, 0.01, 0.1, 1]

# 3. Gráficas de Espectro de Peligro Uniforme

uhs_x_lim = (0.01, 10.00)
uhs_x_ticks = [0.01, 0.10, 1.00, 10.00]

# ===============================================

# %%
# ========== Ejecución del modelo y obtención de output ==========

#!oq dbserver stop
#!oq dbserver start

# %%
#current_file_path = os.path.abspath(__file__)
#current_directory = os.path.dirname(current_file_path)

current_directory = os.getcwd()

dir_route = current_directory + '/Input'
job_route = dir_route + '/job.ini'
# !oq engine --run {job_route}
# Out:
# /Users/emanuelsotoortega/Documents/DeepSkill/seismic-hazard-simulator/.env/lib/python3.11/site-packages/openquake/hazardlib/gsim/base.py:296: ExperimentalWarning: KuehnEtAl2020SInter is experimental and may change in future versions - the user is liable for their application
#   warnings.warn(msg, ExperimentalWarning)
# /Users/emanuelsotoortega/Documents/DeepSkill/seismic-hazard-simulator/.env/lib/python3.11/site-packages/openquake/hazardlib/gsim/base.py:296: ExperimentalWarning: KuehnEtAl2020SSlab is experimental and may change in future versions - the user is liable for their application
#   warnings.warn(msg, ExperimentalWarning)
# [2024-02-19 23:08:01 #42 INFO] emanuelsotoortega@MacBook-Air-de-Emanuel.local running /Users/emanuelsotoortega/Documents/DeepSkill/seismic-hazard-simulator/Generador/Input/job.ini [--hc=None]
# [2024-02-19 23:08:01 #42 INFO] Using engine version 3.18.0
# [2024-02-19 23:08:02 #42 WARNING] Using 8 processpool workers
# [2024-02-19 23:08:02 #42 INFO] Checksum of the inputs: 1730296092 (total size 54.55 KB)
# [2024-02-19 23:08:02 #42 INFO] Running PreClassicalCalculator with concurrent_tasks = 16
# [2024-02-19 23:08:02 #42 INFO] Extracting the hazard sites from the site model
# /Users/emanuelsotoortega/Documents/DeepSkill/seismic-hazard-simulator/.env/lib/python3.11/site-packages/openquake/hazardlib/gsim/base.py:296: ExperimentalWarning: KuehnEtAl2020SInter is experimental and may change in future versions - the user is liable for their application
#   warnings.warn(msg, ExperimentalWarning)
# /Users/emanuelsotoortega/Documents/DeepSkill/seismic-hazard-simulator/.env/lib/python3.11/site-packages/openquake/hazardlib/gsim/base.py:296: ExperimentalWarning: KuehnEtAl2020SSlab is experimental and may change in future versions - the user is liable for their application
#   warnings.warn(msg, ExperimentalWarning)
# [2024-02-19 23:08:02 #42 INFO] Read N=4 hazard sites and L=800 hazard levels
# [2024-02-19 23:08:02 #42 INFO] Reading /Users/emanuelsotoortega/Documents/DeepSkill/seismic-hazard-simulator/Generador/Input/source_model_logic_tree.xml
# /Users/emanuelsotoortega/Documents/DeepSkill/seismic-hazard-simulator/.env/lib/python3.11/site-packages/openquake/hazardlib/gsim/base.py:296: ExperimentalWarning: KuehnEtAl2020SInter is experimental and may change in future versions - the user is liable for their application
#   warnings.warn(msg, ExperimentalWarning)
# /Users/emanuelsotoortega/Documents/DeepSkill/seismic-hazard-simulator/.env/lib/python3.11/site-packages/openquake/hazardlib/gsim/base.py:296: ExperimentalWarning: KuehnEtAl2020SSlab is experimental and may change in future versions - the user is liable for their application
#   warnings.warn(msg, ExperimentalWarning)
# [2024-02-19 23:08:02 #42 INFO] There are 160 logic tree paths(s)
# [2024-02-19 23:08:02 #42 INFO] Reading the source model(s) in parallel
# [2024-02-19 23:08:02 #42 INFO] read_source_model 100% [1 submitted, 0 queued]
# [2024-02-19 23:08:02 #42 INFO] Received 1 * 25.91 KB {'/Users/emanuelsotoortega/Documents/DeepSkill/seismic-hazard-simulator/Generador/Input/source_model.xml': '25.91 KB'} in 0 seconds from read_source_model
# [2024-02-19 23:08:02 #42 INFO] Applying uncertainties
# [2024-02-19 23:08:02 #42 INFO] Applied 40 changes to the composite source model
# [2024-02-19 23:08:02 #42 INFO] Checking sources bounding box using <SiteCollection with 4/4 sites>
# [2024-02-19 23:08:03 #42 INFO] Using pointsource_distance={'default': 100.0}
# [2024-02-19 23:08:03 #42 INFO] Starting preclassical with 6 source groups
# [2024-02-19 23:08:03 #42 INFO] Sent 28 preclassical tasks, 1.13 MB in 0 seconds
# [2024-02-19 23:08:09 #42 INFO] preclassical   3% [28 submitted, 0 queued]
# [2024-02-19 23:08:09 #42 INFO] preclassical   7% [28 submitted, 0 queued]
# [2024-02-19 23:08:09 #42 INFO] preclassical  10% [28 submitted, 0 queued]
# [2024-02-19 23:08:10 #42 INFO] preclassical  14% [28 submitted, 0 queued]
# [2024-02-19 23:08:10 #42 INFO] preclassical  17% [28 submitted, 0 queued]
# [2024-02-19 23:08:10 #42 INFO] preclassical  21% [28 submitted, 0 queued]
# [2024-02-19 23:08:10 #42 INFO] preclassical  25% [28 submitted, 0 queued]
# [2024-02-19 23:08:10 #42 INFO] preclassical  28% [28 submitted, 0 queued]
# [2024-02-19 23:08:12 #42 INFO] preclassical  32% [28 submitted, 0 queued]
# [2024-02-19 23:08:12 #42 INFO] preclassical  35% [28 submitted, 0 queued]
# [2024-02-19 23:08:13 #42 INFO] preclassical  39% [28 submitted, 0 queued]
# [2024-02-19 23:08:14 #42 INFO] preclassical  42% [28 submitted, 0 queued]
# [2024-02-19 23:08:14 #42 INFO] preclassical  46% [28 submitted, 0 queued]
# [2024-02-19 23:08:14 #42 INFO] preclassical  50% [28 submitted, 0 queued]
# [2024-02-19 23:08:15 #42 INFO] preclassical  53% [28 submitted, 0 queued]
# [2024-02-19 23:08:15 #42 INFO] preclassical  57% [28 submitted, 0 queued]
# [2024-02-19 23:08:15 #42 INFO] preclassical  60% [28 submitted, 0 queued]
# [2024-02-19 23:08:15 #42 INFO] preclassical  64% [28 submitted, 0 queued]
# [2024-02-19 23:08:16 #42 INFO] preclassical  67% [28 submitted, 0 queued]
# [2024-02-19 23:08:16 #42 INFO] preclassical  71% [28 submitted, 0 queued]
# [2024-02-19 23:08:18 #42 INFO] preclassical  75% [28 submitted, 0 queued]
# [2024-02-19 23:08:19 #42 INFO] preclassical  78% [28 submitted, 0 queued]
# [2024-02-19 23:08:19 #42 INFO] preclassical  82% [28 submitted, 0 queued]
# [2024-02-19 23:08:20 #42 INFO] preclassical  85% [28 submitted, 0 queued]
# [2024-02-19 23:08:20 #42 INFO] preclassical  89% [28 submitted, 0 queued]
# [2024-02-19 23:08:20 #42 INFO] preclassical  92% [28 submitted, 0 queued]
# [2024-02-19 23:08:20 #42 INFO] preclassical  96% [28 submitted, 0 queued]
# [2024-02-19 23:08:21 #42 INFO] preclassical 100% [28 submitted, 0 queued]
# [2024-02-19 23:08:21 #42 INFO] Mean time per core=13s, std=0.8s, min=12s, max=14s
# [2024-02-19 23:08:21 #42 INFO] Received 28 * 87.87 KB {3: '1.13 MB', 2: '1.07 MB', 5: '77.9 KB', 4: '72.03 KB', 1: '28.27 KB', 0: '26.67 KB', 'after': '160 B', 'before': '160 B'} in 17 seconds from preclassical
# [2024-02-19 23:08:21 #42 INFO] PointSource ruptures: 113_049
# [2024-02-19 23:08:21 #42 INFO] ComplexFaultSource ruptures: 722_208
# [2024-02-19 23:08:21 #42 INFO] There are 6 groups and 40 sources with len(trt_smrs)=1.00
# [2024-02-19 23:08:21 #42 INFO] Storing 147.94 KB of CompositeSourceModel
# [2024-02-19 23:08:21 #42 INFO] tot_weight=1_366_139, max_weight=85_383, num_sources=6_403
# [2024-02-19 23:08:21 #42 INFO] Heaviest: <ComplexFaultSource 17;0.0, weight=4756.9>
# /Users/emanuelsotoortega/Documents/DeepSkill/seismic-hazard-simulator/.env/lib/python3.11/site-packages/openquake/hazardlib/gsim/base.py:296: ExperimentalWarning: KuehnEtAl2020SInter is experimental and may change in future versions - the user is liable for their application
#   warnings.warn(msg, ExperimentalWarning)
# /Users/emanuelsotoortega/Documents/DeepSkill/seismic-hazard-simulator/.env/lib/python3.11/site-packages/openquake/hazardlib/gsim/base.py:296: ExperimentalWarning: KuehnEtAl2020SSlab is experimental and may change in future versions - the user is liable for their application
#   warnings.warn(msg, ExperimentalWarning)
# [2024-02-19 23:08:21 #42 INFO] Considering 786_300 contexts at once
# [2024-02-19 23:08:21 #42 INFO] Allocating 650 KB for the global pmap (Gt=26)
# [2024-02-19 23:08:21 #42 INFO] Sent 16 classical tasks, 3.03 MB in 0 seconds
# [2024-02-19 23:08:37 #42 INFO] classical   5% [17 submitted, 2 queued]
# [2024-02-19 23:08:40 #42 INFO] classical  11% [18 submitted, 1 queued]
# [2024-02-19 23:08:44 #42 INFO] classical  15% [19 submitted, 0 queued]
# [2024-02-19 23:08:44 #42 INFO] classical  21% [19 submitted, 0 queued]
# [2024-02-19 23:08:45 #42 INFO] classical  26% [19 submitted, 0 queued]
# [2024-02-19 23:08:47 #42 INFO] classical  31% [19 submitted, 0 queued]
# [2024-02-19 23:08:48 #42 INFO] classical  36% [19 submitted, 0 queued]
# [2024-02-19 23:08:49 #42 INFO] classical  42% [19 submitted, 0 queued]
# [2024-02-19 23:09:02 #42 INFO] classical  47% [19 submitted, 0 queued]
# [2024-02-19 23:09:07 #42 INFO] classical  52% [19 submitted, 0 queued]
# [2024-02-19 23:09:11 #42 INFO] classical  57% [19 submitted, 0 queued]
# [2024-02-19 23:09:15 #42 INFO] classical  63% [19 submitted, 0 queued]
# [2024-02-19 23:09:16 #42 INFO] classical  68% [19 submitted, 0 queued]
# [2024-02-19 23:09:18 #42 INFO] classical  73% [19 submitted, 0 queued]
# [2024-02-19 23:09:20 #42 INFO] classical  78% [19 submitted, 0 queued]
# [2024-02-19 23:09:24 #42 INFO] classical  84% [19 submitted, 0 queued]
# [2024-02-19 23:09:35 #42 INFO] classical  89% [19 submitted, 0 queued]
# [2024-02-19 23:09:43 #42 INFO] classical  94% [19 submitted, 0 queued]
# [2024-02-19 23:09:44 #42 INFO] classical 100% [19 submitted, 0 queued]
# [2024-02-19 23:09:44 #42 INFO] Mean time per core=65s, std=11.5s, min=53s, max=82s
# [2024-02-19 23:09:44 #42 INFO] Received 19 * 5.71 MB {'rup_data': '106.3 MB', 'pnemap': '1.96 MB', 'source_data': '246.18 KB', 'cfactor': '2.78 KB', 'grp_id': '95 B', 'task_no': '95 B'} in 82 seconds from classical
# [2024-02-19 23:09:44 #42 INFO] Stored 1.02 MB of PoEs
# [2024-02-19 23:09:44 #42 INFO] cfactor = 1_205_832/1_205_832 = 1.0
# [2024-02-19 23:09:44 #42 INFO] There are 1 slices of poes [1.0 per task]
# [2024-02-19 23:09:44 #42 INFO] Producing 25 KB of hazard curves
# [2024-02-19 23:09:44 #42 INFO] Producing 3.75 KB of hazard maps
# [2024-02-19 23:09:44 #42 INFO] postclassical 100% [1 submitted, 0 queued]
# [2024-02-19 23:09:44 #42 INFO] Received 1 * 29.34 KB {'hcurves-stats': '25.3 KB', 'hmaps-stats': '4.05 KB'} in 0 seconds from postclassical
# [2024-02-19 23:09:44 #42 INFO] Saving hcurves-stats
# [2024-02-19 23:09:44 #42 INFO] Saving hmaps-stats
# [2024-02-19 23:09:44 #42 INFO] Exposing the outputs to the database
# /Users/emanuelsotoortega/Documents/DeepSkill/seismic-hazard-simulator/.env/lib/python3.11/site-packages/openquake/hazardlib/gsim/base.py:296: ExperimentalWarning: KuehnEtAl2020SInter is experimental and may change in future versions - the user is liable for their application
#   warnings.warn(msg, ExperimentalWarning)
# /Users/emanuelsotoortega/Documents/DeepSkill/seismic-hazard-simulator/.env/lib/python3.11/site-packages/openquake/hazardlib/gsim/base.py:296: ExperimentalWarning: KuehnEtAl2020SSlab is experimental and may change in future versions - the user is liable for their application
#   warnings.warn(msg, ExperimentalWarning)
# [2024-02-19 23:09:44 #42 INFO] Stored 13.78 MB on /Users/emanuelsotoortega/oqdata/calc_42.hdf5 in 101 seconds
#   id | name
#  107 | Full Report
#  108 | Hazard Curves
#  109 | Realizations
#  110 | Uniform Hazard Spectra

# %%
lhc = subprocess.getoutput('oq engine --lhc').split('\n')
last_hc = re.split(r'\s+', lhc[-1])
calculation_id = int(last_hc[1])

# %%
output_route = current_directory + '/Output'

if os.path.exists(output_route):
    shutil.rmtree(output_route)

# !oq engine --export-outputs {calculation_id} {output_route}

# %%
hazard_curve_mean_files = os.listdir(output_route)
hazard_curve_mean_csvs = []

for ts in ts_list:
    for csv_file in hazard_curve_mean_files:
        if csv_file.startswith('hazard_curve-mean-' + ts):
            hazard_curve_mean_csvs.append(csv_file)

hazard_uhs_mean_csv = ''

for csv_file in hazard_curve_mean_files:
    if csv_file.startswith('hazard_uhs-mean'):
        hazard_uhs_mean_csv = csv_file

hazard_uhs_mean_csv = output_route + '/' + hazard_uhs_mean_csv

hazard_uhs_mean_df = pd.read_csv(hazard_uhs_mean_csv, header=1)
hazard_uhs_mean_df = hazard_uhs_mean_df.drop(columns=['custom_site_id', 'lon', 'lat'], errors='ignore')

# Number of coordinates

n_coord = len(hazard_uhs_mean_df)

# periods

periods = []
poes = []

for column in hazard_uhs_mean_df.columns:
    poe, period = column.split('~')

    poes.append(float(poe))


    if period == 'PGA': period = 0.01
    else: period = float(period[period.index('(')+1 : -1])

    periods.append(period)

periods = sorted(list(set(periods)))
n_periods = len(periods)

poes = sorted(list(set(poes)), reverse=True)
n_poes = len(poes)

tr_dict = {0.4 : 'Tr= 100 años', 0.1 : 'Tr= 475 años', 0.05 : 'Tr= 1000 años', 0.02 : 'Tr= 2475 años', 0.01 : 'Tr= 5000 años', 0.005 : 'Tr= 10000 años'}
poes_header = ['poe=' + str(poe) + ' - ' + tr_dict[poe] for i, poe in enumerate(poes)]

dir_point_routes = [output_route + '/Coordenada ' + str(i+1) for i in range(n_coord)]

for i in range(n_coord):
    os.mkdir(dir_point_routes[i])

curves_df = []

for coord in range(n_coord):
    curve_df = pd.DataFrame()

    for i, csv_file in enumerate(hazard_curve_mean_csvs):
        curve = pd.read_csv(output_route + '/' + csv_file, header=1)
        curve = curve.drop(columns=['custom_site_id', 'lon', 'lat', 'depth'], errors='ignore')

        curve = curve.iloc[coord, :].transpose().reset_index()

        
        
        curve_df['sa (Ts= ' + str(ts_values[i]) + ')'] = curve['index'].apply(lambda x : float(x[4:]))
        curve_df['poe (Ts= ' + str(ts_values[i]) + ')'] = curve[coord]

        curve_df.to_excel(dir_point_routes[coord] + '/Hazard Curve Mean.xlsx', index=False)

    curves_df.append(curve_df)

for coord in range(n_coord):
    fig, ax = plt.subplots()

    ax.set_title('CURVA DE PROBABILIDAD DE EXCEDENCIA PARA ACELERACIÓN ESPECTRAL\n(PUNTO ' + str(coord+1) + ')')

    ax.set_xscale('log')
    ax.set_xlim(hazard_curve_x_lim[0], hazard_curve_x_lim[1])
    #ax.set_xlim(0.01, 10.00)
    ax.set_xticks(hazard_curve_x_ticks)
    #ax.set_xticks([0.01, 1.00, 10.00])
    ax.set_xlabel('Aceleración espectral (g)')

    ax.set_yscale('log')
    ax.set_ylim(hazard_curve_y_lim[0], hazard_curve_y_lim[1])
    #ax.set_ylim(0.0001, 1)
    ax.set_yticks(hazard_curve_y_ticks)
    #ax.set_yticks([0.0001, 0.001, 0.01, 0.1, 1])
    ax.set_ylabel('Probabilidad de excedencia')

    ax.get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
    ax.get_yaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())

    for i in range(len(ts_values)):
        ax.plot(curves_df[coord].iloc[:, 2 * i], curves_df[coord].iloc[:, 2 * i + 1], label='Ts= ' + str(ts_values[i]) + ' s')

    ax.legend(loc='best')
    plt.grid(True)

    plt.savefig(dir_point_routes[coord] + '/Hazard Curve Mean.png')

uhs_tables = []

for coord in range(n_coord):
    uhs_table = pd.DataFrame()
    uhs_table['period'] = pd.Series(periods)

    for i, poe in enumerate(poes_header):
        uhs_table[poe] = hazard_uhs_mean_df.iloc[coord, i * n_periods : (i+1) * n_periods].reset_index(drop=True)

    uhs_table.to_excel(dir_point_routes[coord] + '/Hazard UHS Mean.xlsx', index=False)

    uhs_tables.append(uhs_table)

for coord in range(n_coord):
    fig, ax = plt.subplots()

    ax.set_title('Espectros de Peligro Uniforme (PUNTO ' + str(coord+1) + ')')

    ax.set_xscale('log')
    ax.set_xlim(uhs_x_lim[0], uhs_x_lim[1])
    #ax.set_xlim(0.01, 10.00)
    ax.set_xticks(uhs_x_ticks)
    #ax.set_xticks([0.01, 0.10, 1.00, 10.00])
    ax.set_xlabel('Periodo (s)')

    #ax.set_ylim(0.0001, 1)
    #ax.set_yticks([0.0001, 0.001, 0.01, 0.1, 1])
    ax.set_ylabel('Aceleración espectral (g)')

    ax.get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
    ax.get_yaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())

    for i, poe in enumerate(reversed(poes_header)):
        ax.plot(uhs_tables[coord]['period'], uhs_tables[coord][poe], label=tr_dict[poes[i]])

    ax.legend(loc='best')
    plt.grid(True)

    plt.savefig(dir_point_routes[coord] + '/Hazard UHS Mean.png')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[14], line 52
#      49 dir_point_routes = [output_route + '/Coordenada ' + str(i+1) for i in range(n_coord)]
#      51 for i in range(n_coord):
# ---> 52     os.mkdir(dir_point_routes[i])
#      54 curves_df = []
#      56 for coord in range(n_coord):
#
# FileExistsError: [Errno 17] File exists: '/Users/emanuelsotoortega/Documents/DeepSkill/seismic-hazard-simulator/Generador/Output/Coordenada 1'
